# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nt=pd.read_csv("D:/Reports_Analysis/netflix_titles/netflix_titles.csv")
nt
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Head()

# %%
nt.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # Tail()

# %%
nt.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %% [markdown]
# # Shape
# --------
# to show the number of rows and columns

# %%
nt.shape
# Out:
# (8807, 12)

# %% [markdown]
# # Size
# -----
# to show No. of total vlaues(elements) in the dataset.

# %%
nt.size
# Out:
# 105684

# %% [markdown]
# # Columns

# %%
nt.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# # dtypes

# %%
nt.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# # info

# %%
nt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ### Task. 1. Is ther any Duplicate Record in this dataset? If Yes, Then remove the duplicate records.

# %% [markdown]
# # duplicate()

# %%
nt.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
nt.shape
# Out:
# (8807, 12)

# %%
nt[nt.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# ### Task. 2. Is there any null values present in any column? Show with heatmap.

# %% [markdown]
# # isnull()

# %%
nt.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %% [markdown]
# # sum()
# ---------
# to count the null values

# %%
nt.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# # seaborn library (Heatmap)

# %%
sns.heatmap(nt.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Ques- For "House of Cards", what is the ShowId and who is the Director of this show ?

# %% [markdown]
# # isin()

# %%
nt[nt["title"].isin(["House of Cards"])]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# # str.contains()

# %%
nt[nt["title"].str.contains("House of Cards")]
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### Ques- In which year highest number of TV shows & Movies were released ? Show with the Bar Graph.

# %% [markdown]
# # dtypes

# %%
nt.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
nt.release_year = nt.release_year.astype(str)
nt.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year    object
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
nt["Date_N"]= pd.to_datetime(nt["release_year"])
nt["Date_N"]
# Out:
# 0      2020-01-01
# 1      2021-01-01
# 2      2021-01-01
# 3      2021-01-01
# 4      2021-01-01
#           ...
# 8802   2007-01-01
# 8803   2018-01-01
# 8804   2009-01-01
# 8805   2006-01-01
# 8806   2015-01-01
# Name: Date_N, Length: 8807, dtype: datetime64[ns]

# %%
nt.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year            object
# rating                  object
# duration                object
# listed_in               object
# description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
nt.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added release_year rating   duration  \
# 0  September 25, 2021         2020  PG-13     90 min
# 1  September 24, 2021         2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # dt.year.value_counts()

# %%
nt["Date_N"].dt.year.value_counts()
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: Date_N, Length: 74, dtype: int64

# %% [markdown]
# # Bar graph

# %%
nt.release_year.dtype
# Out:
# dtype('O')

# %%
plt.pie(nt.release_year.value_counts())
plt.show()

# %%
nt.release_year.value_counts().shape
# Out:
# (74,)

# %%
sns.countplot(x=nt.release_year)
# Out:
# <AxesSubplot:xlabel='release_year', ylabel='count'>

# %%
nt['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x=nt['Date_N'].dt.year.value_counts())
# Out:
# <AxesSubplot:xlabel='Date_N', ylabel='count'>

# %% [markdown]
# ### Ques- How many Movies & TV Shows are in the dataset ? Show with the Bar Graph.

# %% [markdown]
# # groupby()

# %%
nt.groupby("type").type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %% [markdown]
# # Countplot()

# %%
sns.countplot(nt['type'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %% [markdown]
# ### Show all the movies that were released in year 2000

# %% [markdown]
# # Creating new column

# %%
nt['Year']= nt['Date_N'].dt.year
nt.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added release_year rating   duration  \
# 0  September 25, 2021         2020  PG-13     90 min
# 1  September 24, 2021         2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N  Year
# 0  As her father nears the end of his life, filmm... 2020-01-01  2020
# 1  After crossing paths at a party, a Cape Town t... 2021-01-01  2021

# %% [markdown]
# # Filtering

# %%
nt[(nt['type']== 'Movie') & (nt['Year']==2000)]
# Out:
#      show_id   type                                              title  \
# 180     s181  Movie                 The Nutty Professor II: The Klumps
# 350     s351  Movie                                      Space Cowboys
# 359     s360  Movie                       The Original Kings of Comedy
# 566     s567  Movie                                   Charlie's Angels
# 593     s594  Movie                                           Snow Day
# 779     s780  Movie                                  Battlefield Earth
# 952     s953  Movie                               The Whole Nine Yards
# 3472   s3473  Movie                        Rugrats in Paris: The Movie
# 4545   s4546  Movie             Monty Python: Before the Flying Circus
# 4723   s4724  Movie                                               Fiza
# 4956   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 5953   s5954  Movie                             Joseph: King of Dreams
# ...

# %%
nt[(nt['type']== 'Movie') & (nt['Year']==2000)].shape
# Out:
# (33, 14)

# %%
# Ques- Show all the title of all TV Shows that were released in india Only.

# %%
# Filtering...........
#........

nt[(nt['type']== 'TV Show') & (nt['country']=='India')][['title']]
# Out:
#                                    title
# 4                           Kota Factory
# 39                          Chhota Bheem
# 50                         Dharmakshetra
# 66         Raja Rasoi Aur Anya Kahaniyan
# 69        Stories by Rabindranath Tagore
# ...                                  ...
# 8173                           Thackeray
# 8235                         The Calling
# 8321  The Golden Years with Javed Akhtar
# 8349              The House That Made Me
# 8775                     Yeh Meri Family
#
# [79 rows x 1 columns]

# %% [markdown]
# ### Ques-> Show top 10 Directors, who gave the highest number of TV Shows & Movies to netflix ?

# %%
nt['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %% [markdown]
# ### Ques-> Show all the records, where "type of movies and listed_in comedies" or Country is United Kingdom".

# %%
nt[(nt['type']=='Movie') & ((nt['listed_in']=='Comedies') | (nt['country']=='United Kingdom'))]
# Out:
#      show_id   type                          title  \
# 27       s28  Movie                      Grown Ups
# 152     s153  Movie  Janoskians: Untold and Untrue
# 182     s183  Movie    Welcome Home Roscoe Jenkins
# 233     s234  Movie                    Count Me In
# 292     s293  Movie                        Quartet
# ...      ...    ...                            ...
# 8732   s8733  Movie                  White Chamber
# 8733   s8734  Movie                   White Island
# 8737   s8738  Movie     Why Are We Getting So Fat?
# 8744   s8745  Movie                       Williams
# 8786   s8787  Movie                   You Can Tutu
#
#                                     director  \
# 27                              Dennis Dugan
# 152                             Brett Weiner
# 182                           Malcolm D. Lee
# 233                                  Mark Lo
# 292                           Dustin Hoffman
# ...                                      ...
# ...

# %%
nt[(nt['type']=='Movie') & (nt['listed_in']=='Comedies') | (nt['country']=='United Kingdom')]
# Out:
#      show_id     type                                   title  \
# 8         s9  TV Show           The Great British Baking Show
# 27       s28    Movie                               Grown Ups
# 32       s33  TV Show                           Sex Education
# 65       s66  TV Show                            Numberblocks
# 72       s73  TV Show  Jack Whitehall: Travels with My Father
# ...      ...      ...                                     ...
# 8740   s8741  TV Show                             Wild Alaska
# 8741   s8742  TV Show                             Wild Arabia
# 8744   s8745    Movie                                Williams
# 8758   s8759  TV Show                  World's Busiest Cities
# 8786   s8787    Movie                            You Can Tutu
#
#              director                                               cast  \
# 8     Andy Devonshire  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %% [markdown]
# ### Ques-> In how many movies/shows, Tom Cruise was Cast ?

# %% [markdown]
# # filtering()

# %%
nt[nt['cast']=='Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_N, Year]
# Index: []

# %% [markdown]
# # str,contains()

# %%
# nt[nt['cast'].str.contains('Tom Cruise')]

# %% [markdown]
# ##### we need to remove NaN data firstly

# %%
nt_new= nt.dropna()
nt_new.head(2)
# Out:
#   show_id     type                          title         director  \
# 7      s8    Movie                        Sankofa     Haile Gerima
# 8      s9  TV Show  The Great British Baking Show  Andy Devonshire
#
#                                                 cast  \
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country          date_added  \
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
#
#   release_year rating   duration  \
# 7         1993  TV-MA    125 min
# 8         2021  TV-14  9 Seasons
#
#                                           listed_in  \
# 7  Dramas, Independent Movies, International Movies
# 8                      British TV Shows, Reality TV
#
#                                          description     Date_N  Year
# ...

# %%
nt_new[nt_new['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 341     s342  Movie  Magnolia  Paul Thomas Anderson
# 1254   s1255  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 341   John C. Reilly, Philip Baker Hall, Tom Cruise,...  United States
# 1254  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#           date_added release_year rating duration                   listed_in  \
# 341   August 1, 2021         1999      R  189 min  Dramas, Independent Movies
# 1254   March 1, 2021         1988      R  134 min      Classic Movies, Dramas
#
#                                             description     Date_N  Year
# 341   Through chance, history and divine interventio... 1999-01-01  1999
# 1254  Motivated by money, a selfish workaholic seeki... 1988-01-01  1988

# %% [markdown]
# ### Ques-> what are the different Rating defined by Netflix ?

# %% [markdown]
# # nunique()

# %%
nt['rating'].nunique()
# Out:
# 17

# %% [markdown]
# # unique()

# %%
nt['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
#  ### Ques-> How many movies got 'TV-14' rating in canada ?

# %%
nt[(nt['type']=='Movie') & (nt['country']=='Canada') & (nt['rating']=='TV-14')]
# Out:
#      show_id   type                                        title  \
# 157     s158  Movie                                     Level 16
# 1279   s1280  Movie   Made You Look: A True Story About Fake Art
# 2769   s2770  Movie               There's Something in the Water
# 3424   s3425  Movie  Martin Matte: La vie, la mort...eh la la..!
# 5972   s5973  Movie                             #cats_the_mewvie
# 5973   s5974  Movie                                        #Roxy
# 6192   s6193  Movie                               At First Light
# 6537   s6538  Movie                   Counterfeiting in Suburbia
# 7334   s7335  Movie                            Long Time Running
# 7916   s7917  Movie                   Sadie's Last Days on Earth
# 7936   s7937  Movie                                   Sardaar ji
# 8178   s8179  Movie                  The Accountant of Auschwitz
# 8566   s8567  Movie                         The Wrong Babysitter
#
#                                     director  \
# ...

# %% [markdown]
# ### Ques-> We also want to know How many movies got 'TV-14' rating containing canada Country ?

# %% [markdown]
# #### we need to remove null values elements

# %%
nt_country=nt.dropna()
nt_country.shape
# Out:
# (5332, 14)

# %%
nt[(nt['type']=='Movie') & (nt['country'].str.contains('Canada')) & (nt['rating']=='TV-14')].head(5)
# Out:
#      show_id   type                                       title  \
# 157     s158  Movie                                    Level 16
# 1001   s1002  Movie                                    Oloibiri
# 1279   s1280  Movie  Made You Look: A True Story About Fake Art
# 1719   s1720  Movie               We Are All For The Fatherland
# 1831   s1832  Movie                                    Whispers
#
#                 director                                               cast  \
# 157   Danishka Esterhazy  Katie Douglas, Celina Martin, Peter Outerbridg...
# 1001       Curtis Graham  Olu Jacobs, Richard Mofe-Damijo, William R. Mo...
# 1279        Barry Avrich                                                NaN
# 1719                 NaN                                                NaN
# 1831     Maroun Baghdadi                          Nadia Tueni, Ziad Rahbani
#
#                              country         date_added release_year rating  \
# ...

# %% [markdown]
# ### Ques-> How many TV show got 'R' rating, after year 2010

# %%
nt[(nt['type']=='TV Show') & (nt['Year']>=2010) & (nt['rating']=='R')]
# Out:
#      show_id     type                                title           director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
# 7593   s7594  TV Show                                Nobel                NaN
#
#                                                    cast country  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
# 7593  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
#
#              date_added release_year rating  duration  \
# 3893     April 25, 2019         2015      R  1 Season
# 7593  December 10, 2016         2016      R  1 Season
#
#                                             listed_in  \
# 3893                                         TV Shows
# 7593  International TV Shows, TV Dramas, TV Thrillers
#
#                                             description     Date_N  Year
# 3893  Trapped at a stagecoach stop as a storm rages ... 2015-01-01  2015
# ...

# %% [markdown]
# ### How many 'Movie' got 'R' rating, after year 2010

# %%
nt[(nt['type']=='Movie') & (nt['Year']>=2010) & (nt['rating']=='R')].shape
# Out:
# (549, 14)

# %% [markdown]
# ### Ques-> What is the maximum duration of a Movie/Show on Netflix ?

# %%
nt['duration'].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
# ...

# %%
nt.duration.dtypes
# Out:
# dtype('O')

# %% [markdown]
# # str.split()

# %%
nt[['mins','unit']]= nt['duration'].str.split(" ",expand=True)

# %%
nt.head(50)
# Out:
#    show_id     type                                              title  \
# 0       s1    Movie                               Dick Johnson Is Dead
# 1       s2  TV Show                                      Blood & Water
# 2       s3  TV Show                                          Ganglands
# 3       s4  TV Show                              Jailbirds New Orleans
# 4       s5  TV Show                                       Kota Factory
# 5       s6  TV Show                                      Midnight Mass
# 6       s7    Movie                   My Little Pony: A New Generation
# 7       s8    Movie                                            Sankofa
# 8       s9  TV Show                      The Great British Baking Show
# 9      s10    Movie                                       The Starling
# 10     s11  TV Show                Vendetta: Truth, Lies and The Mafia
# 11     s12  TV Show                                   Bangkok Breaking
# ...

# %% [markdown]
# # max() of Duration

# %%
nt['mins']
# Out:
# 0        90
# 1         2
# 2         1
# 3         1
# 4         2
#        ...
# 8802    158
# 8803      2
# 8804     88
# 8805     88
# 8806    111
# Name: mins, Length: 8807, dtype: object

# %%
nt['mins']=nt['mins'].astype(float)

# %%
nt.mins.max()
# Out:
# 312.0

# %%
nt.mins.min()
# Out:
# 1.0

# %%
nt.mins.mean()
# Out:
# 69.84688777828259

# %% [markdown]
# ### Ques-> Which individual country has Highest No. of TV Shows ?

# %%
nt.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added release_year rating   duration  \
# 0  September 25, 2021         2020  PG-13     90 min
# 1  September 24, 2021         2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N  Year  mins  \
# 0  As her father nears the end of his life, filmm... 2020-01-01  2020  90.0
# 1  After crossing paths at a party, a Cape Town t... 2021-01-01  2021   2.0
#
#       unit
# 0      min
# ...

# %%
nt_tvshow= nt[nt['type']== 'TV Show']

# %%
nt_tvshow.country.value_counts()
# Out:
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: country, Length: 196, dtype: int64

# %%
nt_tvshow.country.value_counts().head(1)
# Out:
# United States    760
# Name: country, dtype: int64

# %% [markdown]
# ### Ques-> How can we sort the dataset by year ?

# %%
nt.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added release_year rating   duration  \
# 0  September 25, 2021         2020  PG-13     90 min
# 1  September 24, 2021         2021  TV-MA  2 Seasons
# ...

# %%
nt.sort_values('Year') # it show in ascending order.
# Out:
#      show_id     type                                          title  \
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
# 7790   s7791    Movie                                 Prelude to War
# 8205   s8206    Movie                           The Battle of Midway
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8739   s8740    Movie             Why We Fight: The Battle of Russia
# ...      ...      ...                                            ...
# 862     s863  TV Show                                        Special
# 861     s862    Movie             Little Singham Future mein Satakli
# 857     s858  TV Show                                   The Neighbor
# 876     s877  TV Show                                   Alma Matters
# 965     s966  TV Show                                         Yasuke
#
#                          director  \
# 4250                          NaN
# 7790                  Frank Capra
# ...

# %%
nt.sort_values('Year', ascending=False)
# Out:
#      show_id     type                                          title  \
# 693     s694    Movie                         Ali & Ratu Ratu Queens
# 781     s782    Movie          Black Holes | The Edge of All We Know
# 762     s763    Movie                                   Sweet & Sour
# 763     s764  TV Show                                    Sweet Tooth
# 764     s765    Movie                   Trippin' with the Kandasamys
# ...      ...      ...                                            ...
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8763   s8764    Movie                WWII: Report from the Aleutians
# 8205   s8206    Movie                           The Battle of Midway
# 7790   s7791    Movie                                 Prelude to War
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#             director                                               cast  \
# ...

# %% [markdown]
# ### Ques-> Find all the instances where :
#
# ### Category is "movie" and listed_in is "Dramas"
#
# ### or
#
# ### Category is "TV Show" & Listed in "Comedies"

# %%
nt[(nt['type']=="Movie") & (nt['listed_in']=="Dramas")].head(5)
# Out:
#     show_id   type                title             director  \
# 112    s113  Movie                Worth       Sara Colangelo
# 129    s130  Movie   An Unfinished Life      Lasse Hallström
# 142    s143  Movie      Freedom Writers  Richard LaGravenese
# 162    s163  Movie             Marshall      Reginald Hudlin
# 329    s330  Movie  Catch Me If You Can     Steven Spielberg
#
#                                                   cast  \
# 112  Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129  Robert Redford, Jennifer Lopez, Morgan Freeman...
# 142  Hilary Swank, Patrick Dempsey, Scott Glenn, Im...
# 162  Chadwick Boseman, Josh Gad, Kate Hudson, Sterl...
# 329  Leonardo DiCaprio, Tom Hanks, Christopher Walk...
#
#                              country         date_added release_year rating  \
# 112                              NaN  September 3, 2021         2021  PG-13
# 129           Germany, United States  September 1, 2021         2005  PG-13
# ...

# %%
nt[(nt['type']=='Movie') & (nt['listed_in']=="Comedies")].head(5)
# Out:
#     show_id   type                          title        director  \
# 27      s28  Movie                      Grown Ups    Dennis Dugan
# 152    s153  Movie  Janoskians: Untold and Untrue    Brett Weiner
# 182    s183  Movie    Welcome Home Roscoe Jenkins  Malcolm D. Lee
# 342    s343  Movie                    Major Payne     Nick Castle
# 348    s349  Movie                           Poms      Zara Hayes
#
#                                                   cast  \
# 27   Adam Sandler, Kevin James, Chris Rock, David S...
# 152  Jai Brooks, Luke Brooks, James Yammouni, Danie...
# 182  Martin Lawrence, James Earl Jones, Joy Bryant,...
# 342  Damon Wayans, Karyn Parsons, William Hickey, M...
# 348  Diane Keaton, Jacki Weaver, Pam Grier, Rhea Pe...
#
#                            country          date_added release_year rating  \
# 27                   United States  September 20, 2021         2010  PG-13
# 152                  United States   September 1, 2021         2016  TV-MA
# ...

# %%
nt[(nt['type']=="Movie") & (nt['listed_in']=="Dramas") | (nt['type']=='Movie') & (nt['listed_in']=="Comedies")].head(5)
# Out:
#     show_id   type                          title             director  \
# 27      s28  Movie                      Grown Ups         Dennis Dugan
# 112    s113  Movie                          Worth       Sara Colangelo
# 129    s130  Movie             An Unfinished Life      Lasse Hallström
# 142    s143  Movie                Freedom Writers  Richard LaGravenese
# 152    s153  Movie  Janoskians: Untold and Untrue         Brett Weiner
#
#                                                   cast  \
# 27   Adam Sandler, Kevin James, Chris Rock, David S...
# 112  Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129  Robert Redford, Jennifer Lopez, Morgan Freeman...
# 142  Hilary Swank, Patrick Dempsey, Scott Glenn, Im...
# 152  Jai Brooks, Luke Brooks, James Yammouni, Danie...
#
#                     country          date_added release_year rating duration  \
# 27            United States  September 20, 2021         2010  PG-13  103 min
# ...
